# %% [markdown]
# <a href="https://colab.research.google.com/github/dharmaretainer/Chai-Java/blob/main/Tokenization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk
corpus="""Hello I am Aryan Karewar .Now I am doing tokanization practicals"""
print(corpus)
# Out:
# ...
# Hello I am Aryan Karewar .Now I am doing tokanization practicals

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')

from nltk.tokenize import sent_tokenize

corpus = "Hello I am Aryan Karewar. Now I am doing tokenization practicals."
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
sentences = sent_tokenize(corpus)

print(sentences)
# Out:
# ['Hello I am Aryan Karewar.', 'Now I am doing tokenization practicals.']

# %%
##Tokenization
##Paragraph -->words
##sentence-->words
from nltk.tokenize import word_tokenize
word_tokenize(corpus)
# Out:
# ['Hello',
#  'I',
#  'am',
#  'Aryan',
#  'Karewar',
#  '.',
#  'Now',
#  'I',
#  'am',
#  'doing',
#  'tokenization',
#  'practicals',
#  '.']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  'I',
#  'am',
#  'Aryan',
#  'Karewar',
#  '.',
#  'Now',
#  'I',
#  'am',
#  'doing',
#  'tokenization',
#  'practicals',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer
tokenizer=TreebankWordTokenizer()
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'I',
#  'am',
#  'Aryan',
#  'Karewar.',
#  'Now',
#  'I',
#  'am',
#  'doing',
#  'tokenization',
#  'practicals',
#  '.']
